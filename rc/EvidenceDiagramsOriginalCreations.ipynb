# %% [markdown]
# <a id="top"></a>
# ###### Start
# ***
#
# * [Build Interactive Tabs](#buildPlotImageInteractiveTabs)
#
# ###### Bubble Sort
# ***
#
# * [Build](#buildBubbleSort)
#
# ###### Selection Sort
# ***
#
# * [Build](#buildSelectionSort)
#
# ###### Insertion Sort
# ***
#
# * [Build](#buildinsertionSort)
#
# ###### Merge Sort
# ***
#
# * [Build](#buildMergeSort)
#
# ###### Merge Sort
# ***
#
# * [Build](#buildcountingsort)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="buildPlotImageInteractiveTabs"></a>
# ### Build Interactive Tabs
# ***

# %%
exit()

# %%
# %%script bash
# # clean local URLs
# rm -rf ./rc/Partition/*
# rm -rf ./rc/Process/*
# rm -rf ./rc/Sorted/*
# rm -rf ./rc/Unsorted/*

# %%
from sys import path; path.insert(1,"../src")

# %%
def fResetLoopCounter():
    """Initialise loop counter name to zero.

Input:
Process: assign zero to global integer name nSwap
Output:
"""
    global nSwap
    nSwap=0
# --- END ---

# %%
def fResetLocalURL():
    """Initialise collection of local URLs.

Input:
Process: assign zero elements to global collection name nImagesLocalURL
Output:
"""
    global nImagesLocalURL
    nImagesLocalURL=[]
# --- END ---

# %%
def fAddSwapCount():
    """Count swap operations.
    
Input:
Process: increment global integer name nSwap 
Output:
"""
    global nSwap
    nSwap+=1
# --- END ---

# %%
def fAddLocalURL(nParOuterIndex,nParInnerIndex,nParRC="Process"):
    """Append plot local URLs.

Input: nParOuterIndex (loop outer index); nParInnerIndex (loop inner index); 
    nParRC (preassigned "Process" - inputs: "Unsorted" or "Partition" or "Sorted")
Process: append filepath URLs to global collection name nImagesLocalURL (append)
Output: collection of filepath URLS for use in fAddPlotTabs
"""
    nImagesLocalURL.append(f"./rc/{nParRC}/Outer{nParOuterIndex}Inner{nParInnerIndex}.png")
# --- END ---

# %%
def fAddBarLabels(nParCollection):
    """Add text (s) to the axes at coordinates x and y.

Input: nParCollection
Process: (len; range; matplotlib.pyplot.text) 
Output:
"""
    from matplotlib.pyplot import text
    for nIndex in range(len(nParCollection)):
        text(x=nIndex,y=nParCollection[nIndex],
             s=nParCollection[nIndex],
             ha="center",va="bottom",fontsize=12)
    return nParCollection
# --- END ---

# %%
def fAddBarBlue(nParCollection,nParIndex):
    """Initialise collection of bar plot colours.

Input: nParCollection; nParIndex
Process: unsorted Input=nParCollection bar colours "gray";
    sorted Input=nParCollection bar colours "green";
    comparison process bar colours "blue" (len; sorted; pop; insert)
Output: collection of colours for use in fAddPlot
"""    
    from matplotlib.pyplot import xlabel
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nParCollection) # label over bar

    nComparison=f"{nParCollection[nParIndex]}>{nParCollection[nParIndex+1]}" # xlabel actual label 
    nTrueFalse=nParCollection[nParIndex]>nParCollection[nParIndex+1] # label bool result
    
    nColor=[]
    if nParIndex==-1: # flag unsorted collection
        nColor=["gray"]*len(nParCollection) # bar colors "gray"
    elif nParCollection==sorted(nParCollection): # sorted collection      
        nColor=["green"]*len(nParCollection) # bar colors "green"        
    else: # algorithm walk-through process
        # package matplotlib - module pyplot
        xlabel(xlabel=f"Comparison: {nComparison} = {nTrueFalse} - Swap Count: {nSwap}",fontsize=12)        
        nColor=["gray"]*len(nParCollection) # reset bar colors
        nColor.pop(nParIndex) # remove element "gray"
        nColor.insert(nParIndex,"blue") # insert element "blue"
        nColor.pop(nParIndex+1) # remove adjacent "gray"
        nColor.insert(nParIndex+1,"blue") # insert adjacent "blue"
    return nColor # collection bar colours
# --- END ---

# %%
def fAddBarGreen(nParCollection,nParIndex):
    """Initialise collection of bar plot colours.

Input: nParCollection; nParIndex
Process: unsorted Input=nParCollection bar colours "gray";
    sorted Input=nParCollection bar colours "green";
    sorted partition bar colours "green" (len; append)
Output: collection of colours for use in fAddPlot
"""     
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nParCollection)
    
    nColor=[]
    if nParIndex==len(nParCollection)-1: # determine final position 
        nColor=["gray"]*nParIndex # bar colors "gray"
        nColor.append("green") # final position "green"
    else:
        nColor=["gray"]*nParIndex # bar colors "gray"
        nColor+=["green"]*(len(nParCollection)-nParIndex) # sorted partition "green"
    return nColor # collection bar colours
# --- END ---

# %%
def fAddPlot(nParCollection,nParColor):
    """Make a bar plot at coordinate x with dimension height.
    Bars coloured based on some criteria.

Input: nParCollection; nParColor
Process: (matplotlib.pyplot.box,yticks,bar; len; range)
Output:
"""
    from matplotlib.pyplot import box,yticks,bar
    box(False); # remove plot box
    yticks([]) # remove y-axis ticks
    bar(x=range(len(nParCollection)), # x-axis collection indices
        height=nParCollection, # y-axis actual collection
        color=nParColor, # bar color 
        tick_label=range(len(nParCollection))) # ticks represent indices
# --- END ---

# %%
def fBubbleSortTabs():
    """Populate algorithm Bubble Sort tabs for interative tab display.

Input:
Process: name nTabLabels global collection of string labels - len(nTabLabels)==len(nTabText);
    name nTabText global collection of strings - len(nTabText)==len(nTabLabels);
    name nTabOrder global collection of tab ordering - default is alphabetically
Output: collections for use in fAddPlotTabs
"""
    
    global nTabLabel,nTabText,nTabOrder
    nTabLabel=["Collection"]+["4"]*5+["3"]*4+["2"]*3+["1"]*2+["Sorted"] # plot tab label
    nTabText=["Fig. 1.",
              "Fig. 2. Start pass 0.",
              "Fig. 3. Eq. (3) requires E swap.",
              "Fig. 4. Eq. (3) requires E swap.",
              "Fig. 5. Eq. (3) requires E swap.",
              "Fig. 6. End pass 0.",
              "Fig. 7. Start pass 1.",
              "Fig. 8. Eq. (3) requires E swap.",
              "Fig. 9. Eq. (3) requires E swap.",
              "Fig. 10. End pass 1.",
              "Fig. 11. Start pass 2.",
              "Fig. 12. Eq. (3) requires E swap.",
              "Fig. 13. End Pass 2.",
              "Fig. 14 .Start Pass 3.",
              "Fig. 15. End Pass 3.",
              "Fig. 16."
             ] # report referral text
    nTabOrder=["Collection","4","3","2","1","Sorted"] # default alphabetically reorder
# --- END ---

# %%
def fSelectionSortPlot():
    from matplotlib.pyplot import xlabel
    
    #
    # Pass 0
    #
    
    nCollection=[29,23,17,19,13]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["blue","gray","gray","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Minimum = 29 - Swap Count: 0",fontsize=12)
    savefig(fname=f"./rc/Process/0.png") # Fig. 2. Start pass 0.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/0.png")    
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","blue","gray","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Minimum = 23 - Swap Count: 0",fontsize=12)
    savefig(fname=f"./rc/Process/1.png") # Fig. 3. Set minimum E.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/1.png")    

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","blue","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Minimum = 17 - Swap Count: 0",fontsize=12)
    savefig(fname=f"./rc/Process/2.png") # Fig. 4. Set minimum E.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/2.png")    
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","gray","gray","blue"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Minimum = 13 - Swap Count: 0",fontsize=12)
    savefig(fname=f"./rc/Process/3.png") # Fig. 5. Set minimum E.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/3.png")    

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["blue","gray","gray","gray","blue"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Swap [ 0 ] & [ 4 ] - Swap Count: 1",fontsize=12)
    savefig(fname=f"./rc/Process/4.png") # Fig. 6. Swap minimum E.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/4.png")
    
    nCollection=[13,23,17,19,29]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","gray","gray","gray","gray"])
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Partition/6.png") # Fig. 7. End pass 0.
    close() # close figure window
    nImagesLocalURL.append("./rc/Partition/6.png")
    
    #
    # Pass 1
    #
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","blue","gray","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Minimum = 23 - Swap Count: 1",fontsize=12)
    savefig(fname=f"./rc/Process/7.png") # Fig. 8. Start pass 1.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/7.png")    

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","blue","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Minimum = 17 - Swap Count: 1",fontsize=12)
    savefig(fname=f"./rc/Process/8.png") # Fig. 9. Set minimum E.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/8.png") 

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","blue","blue","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Swap [ 1 ] & [ 2 ] - Swap Count: 2",fontsize=12)
    savefig(fname=f"./rc/Process/9.png") # Fig. 10. Swap minimum E.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/9.png")
    
    nCollection=[13,17,23,19,29]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","gray","gray","gray"])
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Partition/10.png") # Fig. 11. End pass 1.
    close() # close figure window
    nImagesLocalURL.append("./rc/Partition/10.png")

    #
    # Pass 2
    #

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","blue","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Minimum = 23 - Swap Count: 2",fontsize=12)
    savefig(fname=f"./rc/Process/11.png") # Fig. 12. Start pass 2.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/11.png") 
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","gray","blue","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Minimum = 19 - Swap Count: 2",fontsize=12)
    savefig(fname=f"./rc/Process/12.png") # Fig. 13. Set minimum E.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/12.png")
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","blue","blue","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Swap [ 2 ] & [ 3 ] - Swap Count: 3",fontsize=12)
    savefig(fname=f"./rc/Process/13.png") # Fig. 14. Swap minimum E.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/13.png")

    nCollection=[13,17,19,23,29]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","green","gray","gray"])
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Partition/14.png") # Fig. 15. End pass 2.
    close() # close figure window
    nImagesLocalURL.append("./rc/Partition/14.png")
    
    #
    # Pass 3
    #

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","gray","blue","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Minimum = 23 - Swap Count: 4",fontsize=12)
    savefig(fname=f"./rc/Process/15.png") # Fig. 16. Start pass 3.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/15.png") 

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","green","green","gray"])
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Partition/16.png") # Fig. 17. End pass 2.
    close() # close figure window
    nImagesLocalURL.append("./rc/Partition/16.png")

    #
    # Sorted
    #
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","green","green","green"])
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Sorted/17.png") # Fig. 18.
    close() # close figure window
    nImagesLocalURL.append("./rc/Sorted/17.png")
    
# --- END ---

# %%
def fSelectionSortTabs():
    """Populate algorithm Selection Sort tabs for interative tab display.

Input:
Process: name nTabLabels global collection of string labels - len(nTabLabels)==len(nTabText);
    name nTabText global collection of strings - len(nTabText)==len(nTabLabels);
    name nTabOrder global collection of tab ordering - default is alphabetically
Output: collections for use in fAddPlotTabs
"""
    
    global nTabLabel,nTabText,nTabOrder
    nTabLabel=["Collection"]+["0"]*6+["1"]*4+["2"]*4+["3"]*2+["Sorted"] # plot tab label
    nTabText=["Fig. 1.",
              "Fig. 2. Start pass 0.",
              "Fig. 3. Set minimum E.",
              "Fig. 4. Set minimum E.",
              "Fig. 5. Set minimum E.",
              "Fig. 6. Swap minimum E.",
              "Fig. 7. End pass 0.",
              "Fig. 8. Start pass 1.",
              "Fig. 9. Set minimum E.",
              "Fig. 10. Swap minimum E.",
              "Fig. 11. End pass 1.",
              "Fig. 12. Start pass 2.",
              "Fig. 13. Set minimum E.",
              "Fig. 14. Swap minimum E.",
              "Fig. 15. End pass 2.",
              "Fig. 16. Start pass 3.",
              "Fig. 17. End pass 2.",
              "Fig. 18."
             ] # report referral text
    nTabOrder=["Collection","0","1","2","3","Sorted"] # default alphabetically reorder
# --- END ---

# %%
def fInsertionSortPlot():
    from matplotlib.pyplot import xlabel
    
    #
    # Pass 0
    #
    
    nCollection=[47,43,37,41,31]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","red","gray","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Set k at [ 1 ]",fontsize=12)
    savefig(fname=f"./rc/Process/0.png") # Fig. 2. Start pass 0.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/0.png")

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["blue","red","gray","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="E > k = True",fontsize=12)
    savefig(fname=f"./rc/Process/1.png") # Fig. 3. Check E left of k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/1.png")

    nCollection=[43,47,37,41,31]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["red","blue","gray","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="k at [ 0 ] - E at [ 1 ]",fontsize=12)
    savefig(fname=f"./rc/Process/2.png") # Fig. 4. Move E and insert k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/2.png")

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","gray","gray","gray"])
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Partition/3.png") # Fig. 5. End pass 0.
    close() # close figure window
    nImagesLocalURL.append("./rc/Partition/3.png")
    
    #
    # Pass 1
    #

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","red","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Set k at [ 2 ]",fontsize=12)
    savefig(fname=f"./rc/Process/4.png") # Fig. 6. Start pass 1.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/4.png")
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","blue","red","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="E > k = True",fontsize=12)
    savefig(fname=f"./rc/Process/5.png") # Fig. 7. Check E left of k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/5.png")
    
    nCollection=[43,37,47,41,31]    

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","red","blue","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="k at [ 1 ] - E at [ 2 ]",fontsize=12)
    savefig(fname=f"./rc/Process/6.png") # Fig. 8. Move E and insert k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/6.png")

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["blue","red","gray","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="E > k = True",fontsize=12)
    savefig(fname=f"./rc/Process/7.png") # Fig. 9. Check E left of k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/7.png")

    nCollection=[37,43,47,41,31]    
 
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["red","blue","gray","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="k at [ 0 ] - E at [ 1 ]",fontsize=12)
    savefig(fname=f"./rc/Process/8.png") # Fig. 10. Move E and insert k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/8.png")

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","green","gray","gray"])
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Partition/9.png") # Fig. 11. End pass 1.
    close() # close figure window
    nImagesLocalURL.append("./rc/Partition/9.png") 
    
    #
    # Pass 2
    #
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","gray","red","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Set k at [ 3 ]",fontsize=12)
    savefig(fname=f"./rc/Process/10.png") # Fig. 12. Start pass 2
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/10.png")
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","blue","red","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="E > k = True",fontsize=12)
    savefig(fname=f"./rc/Process/11.png") # Fig. 13. Check E left of k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/11.png")

    nCollection=[37,43,41,47,31]    
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","red","blue","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="k at [ 2 ] - E at [ 3 ]",fontsize=12)
    savefig(fname=f"./rc/Process/12.png") # Fig. 14. Move E and insert k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/12.png")
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","blue","red","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="E > k = True",fontsize=12)
    savefig(fname=f"./rc/Process/13.png") # Fig. 15. Check E left of k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/13.png")

    nCollection=[37,41,43,47,31]    
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","red","blue","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="k at [ 1 ] - E at [ 2 ]",fontsize=12)
    savefig(fname=f"./rc/Process/14.png") # Fig. 16. Move E and insert k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/14.png")

    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["blue","red","gray","gray","gray"])
    # package matplotlib - module pyplot
    xlabel(xlabel="E > k = False",fontsize=12)
    savefig(fname=f"./rc/Process/15.png") # Fig. 17. Check E left of k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/15.png")
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","green","green","gray"])
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Partition/16.png") # Fig. 18. End pass 2.
    close() # close figure window
    nImagesLocalURL.append("./rc/Partition/16.png")

    #
    # Pass 3
    #
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","gray","gray","red"])
    # package matplotlib - module pyplot
    xlabel(xlabel="Set k at [ 4 ]",fontsize=12)
    savefig(fname=f"./rc/Process/17.png") # Fig. 19. Start pass 3
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/17.png")
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["blue","blue","blue","blue","red"])
    # package matplotlib - module pyplot
    xlabel(xlabel="E > k = True",fontsize=12)
    savefig(fname=f"./rc/Process/18.png") # Fig. 20. Check all E left of k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/18.png")

    nCollection=[31,37,41,43,47]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["red","blue","blue","blue","blue"])
    # package matplotlib - module pyplot
    xlabel(xlabel="k at [ 0 ]",fontsize=12)
    savefig(fname=f"./rc/Process/19.png") # Fig. 21. Move all E and insert k.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/19.png") 

    #
    # Sorted
    # 
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","green","green","green"])
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Sorted/20.png") # Fig. 22. End pass 3.
    close() # close figure window
    nImagesLocalURL.append("./rc/Sorted/20.png")

# %%
def fInsertionSortTabs():
    """Populate algorithm Insertion Sort tabs for interative tab display.

Input:
Process: name nTabLabels global collection of string labels - len(nTabLabels)==len(nTabText);
    name nTabText global collection of strings - len(nTabText)==len(nTabLabels);
    name nTabOrder global collection of tab ordering - default is alphabetically
Output: collections for use in fAddPlotTabs
"""
    
    global nTabLabel,nTabText,nTabOrder
    nTabLabel=["Collection"]+["1"]*4+["2"]*6+["3"]*7+["4"]*3+["Sorted"] # plot tab label
    nTabText=["Fig. 1.",
              "Fig. 2. Start pass 0.",
              "Fig. 3. Check E left of k.",
              "Fig. 4. Move E and insert k.",
              "Fig. 5. End pass 0.",
              "Fig. 6. Start pass 1.",
              "Fig. 7. Check E left of k.",
              "Fig. 8. Move E and insert k.",
              "Fig. 9. Check E left of k.",
              "Fig. 10. Move E and insert k.",
              "Fig. 11. End pass 1.",
              "Fig. 12. Start pass 2",
              "Fig. 13. Check E left of k.",
              "Fig. 14. Move E and insert k.",
              "Fig. 15. Check E left of k.",
              "Fig. 16. Move E and insert k.",
              "Fig. 17. Check E left of k.",
              "Fig. 18. End pass 2.",
              "Fig. 19. Start pass 3",
              "Fig. 20. Check all E left of k.",
              "Fig. 21. Move all E and insert k.",
              "Fig. 22. End pass 3."           
             ] # report referral text
    nTabOrder=["Collection","1","2","3","4","Sorted"] # default alphabetically reorder
# --- END ---

# %%
def fMergeSortPlot():
    from matplotlib.pyplot import xticks,xlabel
    
    #
    # Partitions
    #
    
    nCollection=[71,59,0,61,67,53]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gold","gold","gray","yellow","yellow","yellow"])    
    # package matplotlib - module pyplot
    xticks([]) # no x-axis ticks
    xlabel(xlabel="n > 0 or 1 = True",fontsize=12)
    savefig(fname=f"./rc/Process/0.png") # Fig. 2. Check for base case.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/0.png")

    nCollection=[71,0,59,0,61,0,67,53]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gold","gray","gold","gray","yellow","gray","yellow","yellow"])
    # package matplotlib - module pyplot
    xticks([]) # no x-axis ticks    
    xlabel(xlabel="n > 0 or 1 = True",fontsize=12)
    savefig(fname=f"./rc/Process/1.png") # Fig. 3. Check for base case.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/1.png")

    nCollection=[71,0,59,0,61,0,67,0,53]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","gray","gray","gray","gray","yellow","gray","yellow"])
    # package matplotlib - module pyplot
    xticks([]) # no x-axis ticks    
    xlabel(xlabel="n > 0 or 1 = True",fontsize=12)
    savefig(fname=f"./rc/Process/2.png") # Fig. 4. Check for base case.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/2.png")
    
    #
    # Merge
    #

    nCollection=[71,59,0,61,67,53]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gold","gold","gray","yellow","yellow","yellow"])
    # package matplotlib - module pyplot
    xticks([]) # no x-axis ticks    
    xlabel(xlabel="Swap(s) required = True",fontsize=12)
    savefig(fname=f"./rc/Process/3.png") # Fig. 5. Merge in-between.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/3.png")
    
    nCollection=[59,71,0,53,61,67]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["blue","blue","gray","blue","yellow","blue"])
    # package matplotlib - module pyplot
    xticks([]) # no x-axis ticks    
    savefig(fname=f"./rc/Process/4.png") # Fig. 6. Eq. (3) requires E swap.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/4.png")

    nCollection=[59,71,53,61,67]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["gray","gray","gray","gray","gray"])
    # package matplotlib - module pyplot
    xticks([]) # no x-axis ticks
    xlabel(xlabel="Swap(s) required = True",fontsize=12)    
    savefig(fname=f"./rc/Process/5.png") # Fig. 7. Merge in-between.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/5.png")     

    nCollection=[59,71,53,61,67]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["blue","blue","blue","blue","blue"])
    # package matplotlib - module pyplot
    xticks([]) # no x-axis ticks    
    savefig(fname=f"./rc/Process/6.png") # Fig. 8. Eq. (3) requires E swap.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/6.png")
    
    #
    # Sorted
    #
    
    nCollection=[53,59,61,67,71]
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","green","green","green"])
    # package matplotlib - module pyplot
    xticks([]) # no x-axis ticks    
    savefig(fname=f"./rc/Sorted/7.png") # Fig. 9.
    close() # close figure window
    nImagesLocalURL.append("./rc/Sorted/7.png")

# %%
def fMergeSortTabs():
    """Populate algorithm Merge Sort tabs for interative tab display.

Input:
Process: name nTabLabels global collection of string labels - len(nTabLabels)==len(nTabText);
    name nTabText global collection of strings - len(nTabText)==len(nTabLabels);
    name nTabOrder global collection of tab ordering - default is alphabetically
Output: collections for use in fAddPlotTabs
"""
    global nTabLabel,nTabText,nTabOrder
    nTabLabel=["Collection"]+["Partitions"]*3+["Merge"]*4+["Sorted"] # plot tab label
    nTabText=["Fig. 1.",
              "Fig. 2. Check for base case.",
              "Fig. 3. Check for base case.",
              "Fig. 4. Check for base case.",
              "Fig. 5. Merge in-between.",
              "Fig. 6. Eq. (3) requires E swap.",
              "Fig. 7. Merge in-between.",
              "Fig. 8. Eq. (3) requires E swap.",
              "Fig. 9."
             ] # report referral text
    nTabOrder=["Collection","Partitions","Merge","Sorted"] # default alphabetically reorder
# --- END ---

# %%
def fCountingSortPlot():
    """Populate algorithm Counting Sort tabs for interative tab display.

Input:
Process: name nTabLabels global collection of string labels - len(nTabLabels)==len(nTabText);
    name nTabText global collection of strings - len(nTabText)==len(nTabLabels);
    name nTabOrder global collection of tab ordering - default is alphabetically
Output: collections for use in fAddPlotTabs
"""    
    from matplotlib.pyplot import hist,xlabel,ylabel,box,savefig,close,xticks

    nCollection=[101,97,83,89,79,79,83,73,83]
    
    # package matplotlib - module pyplot
    hist(nCollection,bins=23)
    xlabel("Key values")
    ylabel("Number of Occurences")
    box(False)
    savefig(fname=f"./rc/Process/0.png") # Fig. 2.
    close() # close figure window
    nImagesLocalURL.append("./rc/Process/0.png")
    
    nCollection=sorted(nCollection)
    
    # module fubar - function fAddBarLabels
    fAddBarLabels(nParCollection=nCollection) # label over bar
    fAddPlot(nCollection,["green","green","green","green","green","green","green","green","green"])
    # package matplotlib - module pyplot
    xticks([]) # no x-axis ticks    
    savefig(fname=f"./rc/Sorted/1.png") # Fig. 3.
    close() # close figure window
    nImagesLocalURL.append("./rc/Sorted/1.png")
# --- END ---

# %%
def fCountingSortTabs():
    """Populate algorithm Counting Sort tabs for interative tab display.

Input:
Process: name nTabLabels global collection of string labels - len(nTabLabels)==len(nTabText);
    name nTabText global collection of strings - len(nTabText)==len(nTabLabels);
    name nTabOrder global collection of tab ordering - default is alphabetically
Output: collections for use in fAddPlotTabs
"""
    global nTabLabel,nTabText,nTabOrder
    nTabLabel=["Collection"]+["Histogram"]+["Sorted"] # plot tab label
    nTabText=["Fig. 1.",
              "Fig. 2.",
              "Fig. 3."
             ] # report referral text
    nTabOrder=["Collection","Histogram","Sorted"] # default alphabetically reorder
# --- END ---

# %%
def fAddPlotTabs(nParAlgorithm,nParImageSize=325):
    """Display plots in an interactive tab.
    Hardcoding labels and custom text.
    Future implement: i) determine length of local url filepath; ii) automate label/text/order. 
    
Input: nParAlgorithm; ParImageSize
Process: (ipyplot._plotting.plot_class_tabs)
Output: separating content into interactive tabs
"""
    from ipyplot._plotting import plot_class_tabs # [1]
    
    if nParAlgorithm=="BubbleSort":
        # module fubar - function fBubbleSortTabs
        fBubbleSortTabs()
    elif nParAlgorithm=="SelectionSort":
        # module fubar - function fSelectionSortTabs
        fSelectionSortTabs()
    elif nParAlgorithm=="InsertionSort":
        # module fubar - function fInsertionSortTabs
        fInsertionSortTabs()
    elif nParAlgorithm=="MergeSort":
        # module fubar - function fMergeSortTabs        
        fMergeSortTabs()
    elif nParAlgorithm=="CountingSort":
        # module fubar - function fCountingSortTabs
        fCountingSortTabs()

    return plot_class_tabs(images=nImagesLocalURL, # global collection URLs
                           labels=nTabLabel, # global collection tabs
                           custom_texts=nTabText, # report referral text 
                           img_width=nParImageSize, # full screen snip  
                           zoom_scale=1.0, # no zoom facility
                           show_url=False, # hide filepath label
                           tabs_order=nTabOrder) # default alphabetically reorder
    
    # [1] K. Żak, "IPyPlot," GitHub, February 2021.
# --- END ---

# %%
# module fubar - function fResetLoopCounter
fResetLoopCounter() # reset loop counter 
# module fubar - function fResetLocalURL    
fResetLocalURL() # reset URL filepaths

# %%
# exit() # do not execute

# %% [markdown]
# # Select Sorting Algorithm

# %% [markdown]
# < [Bubble Sort](#buildBubbleSort) | [Selection Sort](#buildSelectionSort) | [Insertion Sort](#buildinsertionSort) | [Merge Sort](#buildMergeSort) | [Counting Sort](#buildcountingsort) >

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="Bubble-Sort"></a>
# ###### Bubble Sort
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="buildBubbleSort"></a>
# ###### Build
# ***

# %% [markdown]
# - interactive tabs require installation of IPyPlot [7]
#
#
# - IPyPlot can be installed through PyPI:
#
# ```
# pip install ipyplot
# ```
#
#
# - or directly from this repo using pip:
#
# ```
# pip install git+https://github.com/karolzak/ipyplot
# ```

# %% [markdown]
# ###### Start Here
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
nCollection=[11,7,3,5,2] # collection of primes

# %%
from matplotlib.pyplot import savefig,close

# %%
# module fubar - function fAddLocalURL
fAddLocalURL(nParOuterIndex=None,nParInnerIndex=None,nParRC="Unsorted") # assign URL "./rc/Unsorted"
# module fubar - function fAddBarBlue - function fAddPlot
fAddPlot(nParCollection=nCollection, # collection under analysis
         nParColor=fAddBarBlue(nParCollection=nCollection,nParIndex=-1)) # plot gray bar
# package matplotlib - module pyplot
savefig(fname=f"./rc/Unsorted/OuterNoneInnerNone.png")
close() # close figure window

# %%
# define function - fBubbleSort
def fBubbleSort(nParCollection):
    
    for nOuterIndex in range(len(nParCollection)-1,0,-1):        
        for nInnerIndex in range(nOuterIndex):
            
            if nParCollection[nInnerIndex]>nParCollection[nInnerIndex+1]:
                
            # Visualise (Process "BLUE")
            # ==========                
                # module fubar - function fAddSwapCount
                fAddSwapCount() # tally loop counter                
                # module fubar - function fAddLocalURL
                fAddLocalURL(nParOuterIndex=nOuterIndex,nParInnerIndex=nInnerIndex) # preassigned URL "./rc/Process"
                # module fubar - function fAddBarBlue - function fAddPlot
                fAddPlot(nParCollection=nParCollection, # collection under analysis
                         nParColor=fAddBarBlue(nParCollection=nParCollection,nParIndex=nInnerIndex)) # plot blue bar
                # package matplotlib - module pyplot
                savefig(fname=f"./rc/Process/Outer{nOuterIndex}Inner{nInnerIndex}.png")
                close() # close figure window
            # ==========
            # END Visual
                
                nTemporary=nParCollection[nInnerIndex]
                nParCollection[nInnerIndex]=nParCollection[nInnerIndex+1]
                nParCollection[nInnerIndex+1]=nTemporary

        # alternative visualisation criteria
            else:
                
            # Visualise (Process "BLUE")
            # ==========                
                fAddLocalURL(nParOuterIndex=nOuterIndex,nParInnerIndex=nInnerIndex) # preassigned URL "./rc/Process"                
                # module fubar - function fAddBarBlue - function fAddPlot
                fAddPlot(nParCollection=nParCollection, # collection under analysis
                         nParColor=fAddBarBlue(nParCollection=nParCollection,nParIndex=nInnerIndex)) # plot blue bar
                # package matplotlib - module pyplot
                savefig(fname=f"./rc/Process/Outer{nOuterIndex}Inner{nInnerIndex}.png")                
                close() # close figure window
            # ==========
            # END Visual
            
    # Visualise (Partition "GREEN")
    # ==========                 
        fAddLocalURL(nParOuterIndex=nOuterIndex,nParInnerIndex=nInnerIndex,nParRC="Partition") # assign URL "./rc/Partition"
        # module fubar - function fAddBarGreen - function fAddPlot
        fAddPlot(nParCollection=nParCollection, # collection under analysis
                 nParColor=fAddBarGreen(nParCollection=nParCollection,nParIndex=nOuterIndex)) # plot green bar
        # package matplotlib - module pyplot
        savefig(fname=f"./rc/Partition/Outer{nOuterIndex}Inner{nInnerIndex}.png")       
        # package matplotlib - module pyplot
        close() # close figure window
    # ==========
    # END Visual
    
    # module fubar - function fAddLocalURL
    fAddLocalURL(nParOuterIndex=None,nParInnerIndex=None,nParRC="Sorted") # assign URL "./rc/Sorted"
    # module fubar - function fAddBarBlue - function fAddPlot
    fAddPlot(nParCollection=nCollection, # collection under analysis
             nParColor=fAddBarGreen(nParCollection=nCollection,nParIndex=-1)) # plot green bar
    # package matplotlib - module pyplot
    savefig(fname=f"./rc/Sorted/OuterNoneInnerNone.png")
    close() # close figure window

    # module fubar - function fAddPlotTabs
    fAddPlotTabs(nParAlgorithm=fBubbleSort.__name__[1:]) # report plot tabs

# %%
# call function - fBubbleSort
fBubbleSort(nCollection)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-TdvSyiAKgLm8zRetRELhTX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TdvSyiAKgLm8zRetRELhTX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TdvSyiAKgLm8zRetRELhTX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TdvSyiAKgLm8zRetRELhTX:checked ~ #ipyplot-html-viewer-textarea-TdvSyiAKgLm8zRetRELhTX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TdvSyiAKgLm8zRetRELhTX:checked + #ipyplot-html-viewer-label-TdvSyiAKgLm8zRetRELhTX:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-TdvSyiAKgLm8zRetRELhTX">
#         <label id="ipyplot-html-viewer-label-TdvSyiAKgLm8zRetRELhTX" for="ipyplot-html-viewer-toggle-TdvSyiAKgLm8zRetRELhTX">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-TdvSyiAKgLm8zRetRELhTX" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V {
#                 display: none;
#             }
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V + label.ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V:checked + label.ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V ~ .tab {
#                 display: none
#             }
#     #tab9CXcNzrK62myayq9asUMgr:checked ~ .tab.content9CXcNzrK62myayq9asUMgr,#tab6trFA4UHtcbmqS5G4ywQB4:checked ~ .tab.content6trFA4UHtcbmqS5G4ywQB4,#tabZpF3Bwz8wecWCJ4WDugYH5:checked ~ .tab.contentZpF3Bwz8wecWCJ4WDugYH5,#tabXQJ4e9DGomH8LthLbnsL6r:checked ~ .tab.contentXQJ4e9DGomH8LthLbnsL6r,#tab9JoYyC4Kka6HcjJsMZMFLn:checked ~ .tab.content9JoYyC4Kka6HcjJsMZMFLn,#tabSr9QZuAqzWTcLLGCs2BJmp:checked ~ .tab.contentSr9QZuAqzWTcLLGCs2BJmp{ display: block; }</style><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tab9CXcNzrK62myayq9asUMgr" checked /><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tab9CXcNzrK62myayq9asUMgr">Collection</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tab6trFA4UHtcbmqS5G4ywQB4"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tab6trFA4UHtcbmqS5G4ywQB4">4</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tabZpF3Bwz8wecWCJ4WDugYH5"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tabZpF3Bwz8wecWCJ4WDugYH5">3</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tabXQJ4e9DGomH8LthLbnsL6r"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tabXQJ4e9DGomH8LthLbnsL6r">2</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tab9JoYyC4Kka6HcjJsMZMFLn"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tab9JoYyC4Kka6HcjJsMZMFLn">1</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tabSr9QZuAqzWTcLLGCs2BJmp"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tabSr9QZuAqzWTcLLGCs2BJmp">Sorted</label><div class="tab content9CXcNzrK62myayq9asUMgr">
#         <style>
#         #ipyplot-imgs-container-div-VoyS2aRTpbuYKqvKXf4Tc6 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-VoyS2aRTpbuYKqvKXf4Tc6 {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-VoyS2aRTpbuYKqvKXf4Tc6">
#     <div class="ipyplot-placeholder-div-VoyS2aRTpbuYKqvKXf4Tc6">
#         <div id="ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6-boh8Nn2MRHL2NPuDgMViu5" class="ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6-boh8Nn2MRHL2NPuDgMViu5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab content6trFA4UHtcbmqS5G4ywQB4">
#         <style>
#         #ipyplot-imgs-container-div-3mSkmHP2jRX3HBqjmh6WB4 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3mSkmHP2jRX3HBqjmh6WB4 {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4 {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3mSkmHP2jR
# <div>
#         <style>
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V {
#                 display: none;
#             }
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V + label.ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V:checked + label.ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-aof2NYbAjk369fq8WxfT6V ~ .tab {
#                 display: none
#             }
#     #tab9CXcNzrK62myayq9asUMgr:checked ~ .tab.content9CXcNzrK62myayq9asUMgr,#tab6trFA4UHtcbmqS5G4ywQB4:checked ~ .tab.content6trFA4UHtcbmqS5G4ywQB4,#tabZpF3Bwz8wecWCJ4WDugYH5:checked ~ .tab.contentZpF3Bwz8wecWCJ4WDugYH5,#tabXQJ4e9DGomH8LthLbnsL6r:checked ~ .tab.contentXQJ4e9DGomH8LthLbnsL6r,#tab9JoYyC4Kka6HcjJsMZMFLn:checked ~ .tab.content9JoYyC4Kka6HcjJsMZMFLn,#tabSr9QZuAqzWTcLLGCs2BJmp:checked ~ .tab.contentSr9QZuAqzWTcLLGCs2BJmp{ display: block; }</style><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tab9CXcNzrK62myayq9asUMgr" checked /><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tab9CXcNzrK62myayq9asUMgr">Collection</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tab6trFA4UHtcbmqS5G4ywQB4"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tab6trFA4UHtcbmqS5G4ywQB4">4</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tabZpF3Bwz8wecWCJ4WDugYH5"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tabZpF3Bwz8wecWCJ4WDugYH5">3</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tabXQJ4e9DGomH8LthLbnsL6r"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tabXQJ4e9DGomH8LthLbnsL6r">2</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tab9JoYyC4Kka6HcjJsMZMFLn"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tab9JoYyC4Kka6HcjJsMZMFLn">1</label><input class="ipyplot-tab-aof2NYbAjk369fq8WxfT6V" type="radio" name="tabs-aof2NYbAjk369fq8WxfT6V" id="tabSr9QZuAqzWTcLLGCs2BJmp"/><label class="ipyplot-tab-label-aof2NYbAjk369fq8WxfT6V" for="tabSr9QZuAqzWTcLLGCs2BJmp">Sorted</label><div class="tab content9CXcNzrK62myayq9asUMgr">
#         <style>
#         #ipyplot-imgs-container-div-VoyS2aRTpbuYKqvKXf4Tc6 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-VoyS2aRTpbuYKqvKXf4Tc6 {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-VoyS2aRTpbuYKqvKXf4Tc6">
#     <div class="ipyplot-placeholder-div-VoyS2aRTpbuYKqvKXf4Tc6">
#         <div id="ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6-boh8Nn2MRHL2NPuDgMViu5" class="ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VoyS2aRTpbuYKqvKXf4Tc6-boh8Nn2MRHL2NPuDgMViu5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab content6trFA4UHtcbmqS5G4ywQB4">
#         <style>
#         #ipyplot-imgs-container-div-3mSkmHP2jRX3HBqjmh6WB4 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3mSkmHP2jRX3HBqjmh6WB4 {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4 {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4 img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3mSkmHP2jRX3HBqjmh6WB4">
#     <div class="ipyplot-placeholder-div-3mSkmHP2jRX3HBqjmh6WB4">
#         <div id="ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4-hGfokRooJx9Cj3HjUXyaJV" class="ipyplot-content-div-3mSkmHP2jRX3HBqjmh6WB4">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 2. Start pas

# %% [markdown]
# &#x1F6A7; screenshot/save for reference

# %%
# %%script bash
# # copy local URLs / clean working URLs
# rm -rf ./rc/BubbleSort/Unsorted; mv ./rc/Unsorted ./rc/BubbleSort/; mkdir ./rc/Unsorted
# rm -rf ./rc/BubbleSort/Process; mv ./rc/Process ./rc/BubbleSort/; mkdir ./rc/Process
# rm -rf ./rc/BubbleSort/Partition; mv ./rc/Partition ./rc/BubbleSort/; mkdir ./rc/Partition
# rm -rf ./rc/BubbleSort/Sorted; mv ./rc/Sorted ./rc/BubbleSort/; mkdir ./rc/Sorted

# %% [markdown]
# ###### Re-Run
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
exit()

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="Selection-Sort"></a>
# ###### Selection Sort
# ***

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="buildSelectionSort"></a>
# ###### Build
# ***

# %% [markdown]
# - interactive tabs require installation of IPyPlot [7]
#
#
# - IPyPlot can be installed through PyPI:
#
# ```
# pip install ipyplot
# ```
#
#
# - or directly from this repo using pip:
#
# ```
# pip install git+https://github.com/karolzak/ipyplot
# ```

# %% [markdown]
# ###### Start Here
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
nCollection=[29,23,17,19,13] # collection of primes

# %%
from matplotlib.pyplot import savefig,close

# %%
# module fubar - function fAddLocalURL
fAddLocalURL(nParOuterIndex=None,nParInnerIndex=None,nParRC="Unsorted") # assign URL "./rc/Unsorted"
# module fubar - function fAddBarBlue - function fAddPlot
fAddPlot(nParCollection=nCollection, # collection under analysis
         nParColor=fAddBarBlue(nParCollection=nCollection,nParIndex=-1)) # plot gray bar
# package matplotlib - module pyplot
savefig(fname=f"./rc/Unsorted/OuterNoneInnerNone.png")
close() # close figure window

# %%
# function call - fSelectionSortPlot
fSelectionSortPlot()

# %%
# define function - fSelectionSort
def fSelectionSort(nParCollection):
    """Selection Sort Algorithm.
    Source: https://www.geeksforgeeks.org/python-program-for-selection-sort
Input: nParCollection
Process: 
Output: sorted collection (in-place)
""" 
    for nOuterIndex in range(len(nParCollection)): # traverse all elements       
        nMinimumIndex=nOuterIndex # set minimum element        
        for nInnerIndex in range(nOuterIndex+1,len(nParCollection)): # traverse remaining elements
            if nParCollection[nMinimumIndex]>nParCollection[nInnerIndex]: # determine minimum element
                nMinimumIndex=nInnerIndex # minimum element found
        nTemporary=nParCollection[nOuterIndex] # capture current pass
        nParCollection[nOuterIndex]=nParCollection[nMinimumIndex] # swap minimum element
        nParCollection[nMinimumIndex]=nTemporary # swap pass element
    # module fubar - function fAddPlotTabs
    fAddPlotTabs(nParAlgorithm=fSelectionSort.__name__[1:],nParImageSize=275) # report plot tabs        
# --- END ---

# %%
# function call - fSelectionSort
fSelectionSort(nCollection)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ALPRycJNat26dvkuHLZvW2 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ALPRycJNat26dvkuHLZvW2 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ALPRycJNat26dvkuHLZvW2 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ALPRycJNat26dvkuHLZvW2:checked ~ #ipyplot-html-viewer-textarea-ALPRycJNat26dvkuHLZvW2 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ALPRycJNat26dvkuHLZvW2:checked + #ipyplot-html-viewer-label-ALPRycJNat26dvkuHLZvW2:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-ALPRycJNat26dvkuHLZvW2">
#         <label id="ipyplot-html-viewer-label-ALPRycJNat26dvkuHLZvW2" for="ipyplot-html-viewer-toggle-ALPRycJNat26dvkuHLZvW2">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-ALPRycJNat26dvkuHLZvW2" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq {
#                 display: none;
#             }
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq + label.ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq:checked + label.ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq ~ .tab {
#                 display: none
#             }
#     #tabHNWRxXtrioR6XfbfTeUwtj:checked ~ .tab.contentHNWRxXtrioR6XfbfTeUwtj,#tabjVy337TLuKL2Ev2ukoGcM8:checked ~ .tab.contentjVy337TLuKL2Ev2ukoGcM8,#tab2SejgyPARfeHauCTJLxRuG:checked ~ .tab.content2SejgyPARfeHauCTJLxRuG,#tabmAeK7RR3hkUpx4Js8pQHSe:checked ~ .tab.contentmAeK7RR3hkUpx4Js8pQHSe,#tabiufpdfgbmWgUDMi5GhAinE:checked ~ .tab.contentiufpdfgbmWgUDMi5GhAinE,#tabPrtrig2nMa2itbnoAHNnwV:checked ~ .tab.contentPrtrig2nMa2itbnoAHNnwV{ display: block; }</style><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabHNWRxXtrioR6XfbfTeUwtj" checked /><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabHNWRxXtrioR6XfbfTeUwtj">Collection</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabjVy337TLuKL2Ev2ukoGcM8"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabjVy337TLuKL2Ev2ukoGcM8">0</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tab2SejgyPARfeHauCTJLxRuG"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tab2SejgyPARfeHauCTJLxRuG">1</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabmAeK7RR3hkUpx4Js8pQHSe"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabmAeK7RR3hkUpx4Js8pQHSe">2</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabiufpdfgbmWgUDMi5GhAinE"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabiufpdfgbmWgUDMi5GhAinE">3</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabPrtrig2nMa2itbnoAHNnwV"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabPrtrig2nMa2itbnoAHNnwV">Sorted</label><div class="tab contentHNWRxXtrioR6XfbfTeUwtj">
#         <style>
#         #ipyplot-imgs-container-div-8SncHfY7mMVN7ANQbNbC5s {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8SncHfY7mMVN7ANQbNbC5s {
#             width: 275px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s {
#             width: 275px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s img {
#             width: 275px;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8SncHfY7mMVN7ANQbNbC5s">
#     <div class="ipyplot-placeholder-div-8SncHfY7mMVN7ANQbNbC5s">
#         <div id="ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s-hgzjiEtFoY45BhAAXuXEEg" class="ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s-hgzjiEtFoY45BhAAXuXEEg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentjVy337TLuKL2Ev2ukoGcM8">
#         <style>
#         #ipyplot-imgs-container-div-d2Whhq8TcyGG9oBNcMyZKZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-d2Whhq8TcyGG9oBNcMyZKZ {
#             width: 275px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ {
#             width: 275px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-d2Whhq8Tcy
# <div>
#         <style>
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq {
#                 display: none;
#             }
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq + label.ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq:checked + label.ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq ~ .tab {
#                 display: none
#             }
#     #tabHNWRxXtrioR6XfbfTeUwtj:checked ~ .tab.contentHNWRxXtrioR6XfbfTeUwtj,#tabjVy337TLuKL2Ev2ukoGcM8:checked ~ .tab.contentjVy337TLuKL2Ev2ukoGcM8,#tab2SejgyPARfeHauCTJLxRuG:checked ~ .tab.content2SejgyPARfeHauCTJLxRuG,#tabmAeK7RR3hkUpx4Js8pQHSe:checked ~ .tab.contentmAeK7RR3hkUpx4Js8pQHSe,#tabiufpdfgbmWgUDMi5GhAinE:checked ~ .tab.contentiufpdfgbmWgUDMi5GhAinE,#tabPrtrig2nMa2itbnoAHNnwV:checked ~ .tab.contentPrtrig2nMa2itbnoAHNnwV{ display: block; }</style><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabHNWRxXtrioR6XfbfTeUwtj" checked /><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabHNWRxXtrioR6XfbfTeUwtj">Collection</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabjVy337TLuKL2Ev2ukoGcM8"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabjVy337TLuKL2Ev2ukoGcM8">0</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tab2SejgyPARfeHauCTJLxRuG"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tab2SejgyPARfeHauCTJLxRuG">1</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabmAeK7RR3hkUpx4Js8pQHSe"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabmAeK7RR3hkUpx4Js8pQHSe">2</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabiufpdfgbmWgUDMi5GhAinE"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabiufpdfgbmWgUDMi5GhAinE">3</label><input class="ipyplot-tab-BnfhdhjPWpmVhjTmhURNNq" type="radio" name="tabs-BnfhdhjPWpmVhjTmhURNNq" id="tabPrtrig2nMa2itbnoAHNnwV"/><label class="ipyplot-tab-label-BnfhdhjPWpmVhjTmhURNNq" for="tabPrtrig2nMa2itbnoAHNnwV">Sorted</label><div class="tab contentHNWRxXtrioR6XfbfTeUwtj">
#         <style>
#         #ipyplot-imgs-container-div-8SncHfY7mMVN7ANQbNbC5s {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8SncHfY7mMVN7ANQbNbC5s {
#             width: 275px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s {
#             width: 275px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s img {
#             width: 275px;
#         }
#
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8SncHfY7mMVN7ANQbNbC5s">
#     <div class="ipyplot-placeholder-div-8SncHfY7mMVN7ANQbNbC5s">
#         <div id="ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s-hgzjiEtFoY45BhAAXuXEEg" class="ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8SncHfY7mMVN7ANQbNbC5s-hgzjiEtFoY45BhAAXuXEEg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentjVy337TLuKL2Ev2ukoGcM8">
#         <style>
#         #ipyplot-imgs-container-div-d2Whhq8TcyGG9oBNcMyZKZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-d2Whhq8TcyGG9oBNcMyZKZ {
#             width: 275px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ {
#             width: 275px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ img {
#             width: 275px;
#         }
#
#         div.ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-d2Whhq8TcyGG9oBNcMyZKZ">
#     <div class="ipyplot-placeholder-div-d2Whhq8TcyGG9oBNcMyZKZ">
#         <div id="ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ-ArRJ4tgT9WgdXgXMy7Cwpx" class="ipyplot-content-div-d2Whhq8TcyGG9oBNcMyZKZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 2. Start pas

# %% [markdown]
# &#x1F6A7; screenshot/save for reference

# %%
# %%script bash
# # copy local URLs / clean working URLs
# rm -rf ./rc/SelectionSort/Unsorted; mv ./rc/Unsorted ./rc/SelectionSort/; mkdir ./rc/Unsorted
# rm -rf ./rc/SelectionSort/Process; mv ./rc/Process ./rc/SelectionSort/; mkdir ./rc/Process
# rm -rf ./rc/SelectionSort/Partition; mv ./rc/Partition ./rc/SelectionSort/; mkdir ./rc/Partition
# rm -rf ./rc/SelectionSort/Sorted; mv ./rc/Sorted ./rc/SelectionSort/; mkdir ./rc/Sorted

# %% [markdown]
# ###### Re-Run
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
exit()

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="Insertion-Sort"></a>
# ###### Insertion Sort
# ***

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="buildinsertionSort"></a>
# ###### Build
# ***

# %% [markdown]
# - interactive tabs require installation of IPyPlot [7]
#
#
# - IPyPlot can be installed through PyPI:
#
# ```
# pip install ipyplot
# ```
#
#
# - or directly from this repo using pip:
#
# ```
# pip install git+https://github.com/karolzak/ipyplot
# ```

# %% [markdown]
# ###### Start Here
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
nCollection=[47,43,37,41,31] # collection of primes

# %%
from matplotlib.pyplot import savefig,close

# %%
# module fubar - function fAddLocalURL
fAddLocalURL(nParOuterIndex=None,nParInnerIndex=None,nParRC="Unsorted") # assign URL "./rc/Unsorted"
# module fubar - function fAddBarBlue - function fAddPlot
fAddPlot(nParCollection=nCollection, # collection under analysis
         nParColor=fAddBarBlue(nParCollection=nCollection,nParIndex=-1)) # plot gray bar
# package matplotlib - module pyplot
savefig(fname=f"./rc/Unsorted/OuterNoneInnerNone.png")
close() # close figure window

# %%
# function call - fInsertionSortPlot
fInsertionSortPlot()

# %%
# define function - fInsertionSort
def fInsertionSort(nParCollection):
    """Insertion Sort Algorithm.
    Source: https://runestone.academy/runestone/books/published/pythonds/SortSearch/TheInsertionSort.html
Input: nParCollection
Process: 
Output: sorted collection (in-place)
""" 
    for nOuterIndex in range(1,len(nParCollection)): # traverse all [ 1 ]       
        nElement=nParCollection[nOuterIndex] # capture element value
        nElementPosition=nOuterIndex # capture element position
        while nElementPosition>0 and nParCollection[nElementPosition-1]>nElement: # both are True
            nParCollection[nElementPosition]=nParCollection[nElementPosition-1] # current position move
            nElementPosition=nElementPosition-1 # reset element position
        nParCollection[nElementPosition]=nElement # adjacent element move
    # module fubar - function fAddPlotTabs
    fAddPlotTabs(nParAlgorithm=fInsertionSort.__name__[1:],nParImageSize=225) # report plot tabs
# --- END ---

# %%
# function call - fInsertionSort
fInsertionSort(nCollection)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-fcqRHCGTYV6zH7vASHymjx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fcqRHCGTYV6zH7vASHymjx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fcqRHCGTYV6zH7vASHymjx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fcqRHCGTYV6zH7vASHymjx:checked ~ #ipyplot-html-viewer-textarea-fcqRHCGTYV6zH7vASHymjx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fcqRHCGTYV6zH7vASHymjx:checked + #ipyplot-html-viewer-label-fcqRHCGTYV6zH7vASHymjx:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-fcqRHCGTYV6zH7vASHymjx">
#         <label id="ipyplot-html-viewer-label-fcqRHCGTYV6zH7vASHymjx" for="ipyplot-html-viewer-toggle-fcqRHCGTYV6zH7vASHymjx">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-fcqRHCGTYV6zH7vASHymjx" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh {
#                 display: none;
#             }
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh + label.ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh:checked + label.ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh ~ .tab {
#                 display: none
#             }
#     #tabhuCbztdCKnHUYfnpvhoV8R:checked ~ .tab.contenthuCbztdCKnHUYfnpvhoV8R,#tabL6y6p8H7G5EzSUN9VxYG69:checked ~ .tab.contentL6y6p8H7G5EzSUN9VxYG69,#tabEh7aboz5Tf9nH5aUTMBgv8:checked ~ .tab.contentEh7aboz5Tf9nH5aUTMBgv8,#tabHgQMMUDaahC4Gj9yZLp78N:checked ~ .tab.contentHgQMMUDaahC4Gj9yZLp78N,#tabV2XTDHDDKVn6fEeBLbaXsa:checked ~ .tab.contentV2XTDHDDKVn6fEeBLbaXsa,#tabF9iDbxNfi2S33pV96o7Gs2:checked ~ .tab.contentF9iDbxNfi2S33pV96o7Gs2{ display: block; }</style><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabhuCbztdCKnHUYfnpvhoV8R" checked /><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabhuCbztdCKnHUYfnpvhoV8R">Collection</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabL6y6p8H7G5EzSUN9VxYG69"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabL6y6p8H7G5EzSUN9VxYG69">1</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabEh7aboz5Tf9nH5aUTMBgv8"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabEh7aboz5Tf9nH5aUTMBgv8">2</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabHgQMMUDaahC4Gj9yZLp78N"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabHgQMMUDaahC4Gj9yZLp78N">3</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabV2XTDHDDKVn6fEeBLbaXsa"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabV2XTDHDDKVn6fEeBLbaXsa">4</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabF9iDbxNfi2S33pV96o7Gs2"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabF9iDbxNfi2S33pV96o7Gs2">Sorted</label><div class="tab contenthuCbztdCKnHUYfnpvhoV8R">
#         <style>
#         #ipyplot-imgs-container-div-Vd4EhFKFo8sgF9D2e7G3zV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Vd4EhFKFo8sgF9D2e7G3zV {
#             width: 225px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV {
#             width: 225px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV img {
#             width: 225px;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Vd4EhFKFo8sgF9D2e7G3zV">
#     <div class="ipyplot-placeholder-div-Vd4EhFKFo8sgF9D2e7G3zV">
#         <div id="ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV-R2tC5Vb22DkgzKtREsJRqp" class="ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV-R2tC5Vb22DkgzKtREsJRqp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentL6y6p8H7G5EzSUN9VxYG69">
#         <style>
#         #ipyplot-imgs-container-div-HgLJVVMJCTcGf9RKJbKDd3 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HgLJVVMJCTcGf9RKJbKDd3 {
#             width: 225px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3 {
#             width: 225px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HgLJVVMJCT
# <div>
#         <style>
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh {
#                 display: none;
#             }
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh + label.ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh:checked + label.ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh ~ .tab {
#                 display: none
#             }
#     #tabhuCbztdCKnHUYfnpvhoV8R:checked ~ .tab.contenthuCbztdCKnHUYfnpvhoV8R,#tabL6y6p8H7G5EzSUN9VxYG69:checked ~ .tab.contentL6y6p8H7G5EzSUN9VxYG69,#tabEh7aboz5Tf9nH5aUTMBgv8:checked ~ .tab.contentEh7aboz5Tf9nH5aUTMBgv8,#tabHgQMMUDaahC4Gj9yZLp78N:checked ~ .tab.contentHgQMMUDaahC4Gj9yZLp78N,#tabV2XTDHDDKVn6fEeBLbaXsa:checked ~ .tab.contentV2XTDHDDKVn6fEeBLbaXsa,#tabF9iDbxNfi2S33pV96o7Gs2:checked ~ .tab.contentF9iDbxNfi2S33pV96o7Gs2{ display: block; }</style><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabhuCbztdCKnHUYfnpvhoV8R" checked /><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabhuCbztdCKnHUYfnpvhoV8R">Collection</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabL6y6p8H7G5EzSUN9VxYG69"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabL6y6p8H7G5EzSUN9VxYG69">1</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabEh7aboz5Tf9nH5aUTMBgv8"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabEh7aboz5Tf9nH5aUTMBgv8">2</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabHgQMMUDaahC4Gj9yZLp78N"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabHgQMMUDaahC4Gj9yZLp78N">3</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabV2XTDHDDKVn6fEeBLbaXsa"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabV2XTDHDDKVn6fEeBLbaXsa">4</label><input class="ipyplot-tab-kvgFVFSp7YwDCozqkJkaHh" type="radio" name="tabs-kvgFVFSp7YwDCozqkJkaHh" id="tabF9iDbxNfi2S33pV96o7Gs2"/><label class="ipyplot-tab-label-kvgFVFSp7YwDCozqkJkaHh" for="tabF9iDbxNfi2S33pV96o7Gs2">Sorted</label><div class="tab contenthuCbztdCKnHUYfnpvhoV8R">
#         <style>
#         #ipyplot-imgs-container-div-Vd4EhFKFo8sgF9D2e7G3zV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Vd4EhFKFo8sgF9D2e7G3zV {
#             width: 225px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV {
#             width: 225px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV img {
#             width: 225px;
#         }
#
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Vd4EhFKFo8sgF9D2e7G3zV">
#     <div class="ipyplot-placeholder-div-Vd4EhFKFo8sgF9D2e7G3zV">
#         <div id="ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV-R2tC5Vb22DkgzKtREsJRqp" class="ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Vd4EhFKFo8sgF9D2e7G3zV-R2tC5Vb22DkgzKtREsJRqp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentL6y6p8H7G5EzSUN9VxYG69">
#         <style>
#         #ipyplot-imgs-container-div-HgLJVVMJCTcGf9RKJbKDd3 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HgLJVVMJCTcGf9RKJbKDd3 {
#             width: 225px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3 {
#             width: 225px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3 img {
#             width: 225px;
#         }
#
#         div.ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-HgLJVVMJCTcGf9RKJbKDd3">
#     <div class="ipyplot-placeholder-div-HgLJVVMJCTcGf9RKJbKDd3">
#         <div id="ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3-EM9fTPobmRfRVDz4D5i5HD" class="ipyplot-content-div-HgLJVVMJCTcGf9RKJbKDd3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 2. Start pas

# %% [markdown]
# &#x1F6A7; screenshot/save for reference

# %%
# %%script bash
# # copy local URLs / clean working URLs
# rm -rf ./rc/InsertionSort/Unsorted; mv ./rc/Unsorted ./rc/InsertionSort/; mkdir ./rc/Unsorted
# rm -rf ./rc/InsertionSort/Process; mv ./rc/Process ./rc/InsertionSort/; mkdir ./rc/Process
# rm -rf ./rc/InsertionSort/Partition; mv ./rc/Partition ./rc/InsertionSort/; mkdir ./rc/Partition
# rm -rf ./rc/InsertionSort/Sorted; mv ./rc/Sorted ./rc/InsertionSort/; mkdir ./rc/Sorted

# %% [markdown]
# ###### Re-Run
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
exit()

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="Merge-Sort"></a>
# ###### Merge Sort
# ***

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="buildMergeSort"></a>
# ###### Build
# ***

# %% [markdown]
# - interactive tabs require installation of IPyPlot [7]
#
#
# - IPyPlot can be installed through PyPI:
#
# ```
# pip install ipyplot
# ```
#
#
# - or directly from this repo using pip:
#
# ```
# pip install git+https://github.com/karolzak/ipyplot
# ```

# %% [markdown]
# ###### Start Here
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
nCollection=[71,59,61,67,53] # collection of primes

# %%
from matplotlib.pyplot import xticks,savefig,close

# %%
# module fubar - function fAddLocalURL
fAddLocalURL(nParOuterIndex=None,nParInnerIndex=None,nParRC="Unsorted") # assign URL "./rc/Unsorted"
# module fubar - function fAddBarBlue - function fAddPlot
fAddPlot(nParCollection=nCollection, # collection under analysis
         nParColor=fAddBarBlue(nParCollection=nCollection,nParIndex=-1)) # plot gray bar
xticks([]) # no x-axis ticks
# package matplotlib - module pyplot
savefig(fname=f"./rc/Unsorted/OuterNoneInnerNone.png")
close() # close figure window

# %%
# define function - fMergeSort
def fMergeSort(nParCollection):
    """Merge Sort Algorithm.
    Source: https://runestone.academy/runestone/books/published/pythonds/SortSearch/TheMergeSort.html
Input: nParCollection
Process: 
Output: sorted collection (in-place)
""" 
    if len(nParCollection)>1: # check base case
        nAppropriatelyHalf=len(nParCollection)//2 # floor division appropriate        
        nLeftPartition=nParCollection[:nAppropriatelyHalf] # slice appropriately half        
        nRightPartition=nParCollection[nAppropriatelyHalf:] # slice appropriately half        
        fMergeSort(nLeftPartition) # recursion call itself
        fMergeSort(nRightPartition) # recursion call itself

        nLeftCounter,nRightCounter,nLoopCounter=0,0,0 # initialise loop counters
        
        while nLeftCounter<len(nLeftPartition) and nRightCounter<len(nRightPartition):
            if nLeftPartition[nLeftCounter]<=nRightPartition[nRightCounter]: # ensure algorithm stable
                nParCollection[nLoopCounter]=nLeftPartition[nLeftCounter]                
                nLeftCounter+=1
            else:
                nParCollection[nLoopCounter]=nRightPartition[nRightCounter]                
                nRightCounter+=1
            nLoopCounter+=1
            
        while nLeftCounter<len(nLeftPartition):
            nParCollection[nLoopCounter]=nLeftPartition[nLeftCounter]            
            nLeftCounter+=1
            nLoopCounter+=1
            
        while nRightCounter<len(nRightPartition):
            nParCollection[nLoopCounter]=nRightPartition[nRightCounter]            
            nRightCounter+=1
            nLoopCounter+=1

    if nParCollection==[53, 59, 61, 67, 71]: # recursion execute once
        # module fubar - function fAddPlotTabs
        fAddPlotTabs(nParAlgorithm=fMergeSort.__name__[1:]) # report plot tabs
# --- END ---

# %%
# function call - fMergeSortPlot
fMergeSortPlot()

# %%
# function call - fMergeSort
fMergeSort(nCollection)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SXmr9J46px3u9UCWNkeKQc {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SXmr9J46px3u9UCWNkeKQc {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SXmr9J46px3u9UCWNkeKQc {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SXmr9J46px3u9UCWNkeKQc:checked ~ #ipyplot-html-viewer-textarea-SXmr9J46px3u9UCWNkeKQc {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SXmr9J46px3u9UCWNkeKQc:checked + #ipyplot-html-viewer-label-SXmr9J46px3u9UCWNkeKQc:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-SXmr9J46px3u9UCWNkeKQc">
#         <label id="ipyplot-html-viewer-label-SXmr9J46px3u9UCWNkeKQc" for="ipyplot-html-viewer-toggle-SXmr9J46px3u9UCWNkeKQc">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-SXmr9J46px3u9UCWNkeKQc" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp {
#                 display: none;
#             }
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp + label.ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp:checked + label.ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp ~ .tab {
#                 display: none
#             }
#     #tab8PrW6m5jWJiLsLhHrmsGpq:checked ~ .tab.content8PrW6m5jWJiLsLhHrmsGpq,#tabWpcj8PctfMmSqSwRjzskiM:checked ~ .tab.contentWpcj8PctfMmSqSwRjzskiM,#tabQz3BKgCdgt43G46bJpuzPq:checked ~ .tab.contentQz3BKgCdgt43G46bJpuzPq,#tabX326ApFMjeyWCNqXjqpwoa:checked ~ .tab.contentX326ApFMjeyWCNqXjqpwoa{ display: block; }</style><input class="ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp" type="radio" name="tabs-KT8ya6fQpDWMPkhBM8hXCp" id="tab8PrW6m5jWJiLsLhHrmsGpq" checked /><label class="ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp" for="tab8PrW6m5jWJiLsLhHrmsGpq">Collection</label><input class="ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp" type="radio" name="tabs-KT8ya6fQpDWMPkhBM8hXCp" id="tabWpcj8PctfMmSqSwRjzskiM"/><label class="ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp" for="tabWpcj8PctfMmSqSwRjzskiM">Partitions</label><input class="ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp" type="radio" name="tabs-KT8ya6fQpDWMPkhBM8hXCp" id="tabQz3BKgCdgt43G46bJpuzPq"/><label class="ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp" for="tabQz3BKgCdgt43G46bJpuzPq">Merge</label><input class="ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp" type="radio" name="tabs-KT8ya6fQpDWMPkhBM8hXCp" id="tabX326ApFMjeyWCNqXjqpwoa"/><label class="ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp" for="tabX326ApFMjeyWCNqXjqpwoa">Sorted</label><div class="tab content8PrW6m5jWJiLsLhHrmsGpq">
#         <style>
#         #ipyplot-imgs-container-div-BaozAZq2wVfoKgYmBjqzpr {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-BaozAZq2wVfoKgYmBjqzpr {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-BaozAZq2wVfoKgYmBjqzpr">
#     <div class="ipyplot-placeholder-div-BaozAZq2wVfoKgYmBjqzpr">
#         <div id="ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr-VnqrW2uSn2Fe3uL7H2rwks" class="ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr-VnqrW2uSn2Fe3uL7H2rwks">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentWpcj8PctfMmSqSwRjzskiM">
#         <style>
#         #ipyplot-imgs-container-div-geQZpWqLfQTDdEWSFCwmu6 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-geQZpWqLfQTDdEWSFCwmu6 {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 span.ipyplot-img-expand:hover {
# <div>
#         <style>
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp {
#                 display: none;
#             }
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp + label.ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp:checked + label.ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp ~ .tab {
#                 display: none
#             }
#     #tab8PrW6m5jWJiLsLhHrmsGpq:checked ~ .tab.content8PrW6m5jWJiLsLhHrmsGpq,#tabWpcj8PctfMmSqSwRjzskiM:checked ~ .tab.contentWpcj8PctfMmSqSwRjzskiM,#tabQz3BKgCdgt43G46bJpuzPq:checked ~ .tab.contentQz3BKgCdgt43G46bJpuzPq,#tabX326ApFMjeyWCNqXjqpwoa:checked ~ .tab.contentX326ApFMjeyWCNqXjqpwoa{ display: block; }</style><input class="ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp" type="radio" name="tabs-KT8ya6fQpDWMPkhBM8hXCp" id="tab8PrW6m5jWJiLsLhHrmsGpq" checked /><label class="ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp" for="tab8PrW6m5jWJiLsLhHrmsGpq">Collection</label><input class="ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp" type="radio" name="tabs-KT8ya6fQpDWMPkhBM8hXCp" id="tabWpcj8PctfMmSqSwRjzskiM"/><label class="ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp" for="tabWpcj8PctfMmSqSwRjzskiM">Partitions</label><input class="ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp" type="radio" name="tabs-KT8ya6fQpDWMPkhBM8hXCp" id="tabQz3BKgCdgt43G46bJpuzPq"/><label class="ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp" for="tabQz3BKgCdgt43G46bJpuzPq">Merge</label><input class="ipyplot-tab-KT8ya6fQpDWMPkhBM8hXCp" type="radio" name="tabs-KT8ya6fQpDWMPkhBM8hXCp" id="tabX326ApFMjeyWCNqXjqpwoa"/><label class="ipyplot-tab-label-KT8ya6fQpDWMPkhBM8hXCp" for="tabX326ApFMjeyWCNqXjqpwoa">Sorted</label><div class="tab content8PrW6m5jWJiLsLhHrmsGpq">
#         <style>
#         #ipyplot-imgs-container-div-BaozAZq2wVfoKgYmBjqzpr {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-BaozAZq2wVfoKgYmBjqzpr {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-BaozAZq2wVfoKgYmBjqzpr">
#     <div class="ipyplot-placeholder-div-BaozAZq2wVfoKgYmBjqzpr">
#         <div id="ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr-VnqrW2uSn2Fe3uL7H2rwks" class="ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-BaozAZq2wVfoKgYmBjqzpr-VnqrW2uSn2Fe3uL7H2rwks">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentWpcj8PctfMmSqSwRjzskiM">
#         <style>
#         #ipyplot-imgs-container-div-geQZpWqLfQTDdEWSFCwmu6 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-geQZpWqLfQTDdEWSFCwmu6 {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-geQZpWqLfQTDdEWSFCwmu6">
#     <div class="ipyplot-placeholder-div-geQZpWqLfQTDdEWSFCwmu6">
#         <div id="ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6-gaK3ELZm74ckrpgyj7spuw" class="ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 2. Check for base case.</h4><img src="./rc/Process/0.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6-gaK3ELZm74ckrpgyj7spuw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-geQZpWqLfQTDdEWSFCwmu6">
#         <div id="ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6-ck8bKjAhbXmFjStpzctee3" class="ipyplot-content-div-geQZpWqLfQTDdEWSFCwmu6">
#             <h4 style="font-size: 12px; word-wrap: bre

# %% [markdown]
# &#x1F6A7; screenshot/save for reference

# %%
# %%script bash
# # copy local URLs / clean working URLs
# rm -rf ./rc/MergeSort/Unsorted; mv ./rc/Unsorted ./rc/MergeSort/; mkdir ./rc/Unsorted
# rm -rf ./rc/MergeSort/Process; mv ./rc/Process ./rc/MergeSort/; mkdir ./rc/Process
# rm -rf ./rc/MergeSort/Partition; mv ./rc/Partition ./rc/MergeSort/; mkdir ./rc/Partition
# rm -rf ./rc/MergeSort/Sorted; mv ./rc/Sorted ./rc/MergeSort/; mkdir ./rc/Sorted

# %% [markdown]
# ###### Re-Run
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
exit()

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="Counting-Sort"></a>
# ###### Counting Sort
# ***

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="buildcountingsort"></a>
# ###### Build
# ***

# %% [markdown]
# - interactive tabs require installation of IPyPlot [7]
#
#
# - IPyPlot can be installed through PyPI:
#
# ```
# pip install ipyplot
# ```
#
#
# - or directly from this repo using pip:
#
# ```
# pip install git+https://github.com/karolzak/ipyplot
# ```

# %% [markdown]
# ###### Start Here
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
nCollection=[101,97,83,89,79,79,83,73,83] # collection of primes

# %%
from matplotlib.pyplot import savefig,close,xticks

# %%
# module fubar - function fAddLocalURL
fAddLocalURL(nParOuterIndex=None,nParInnerIndex=None,nParRC="Unsorted") # assign URL "./rc/Unsorted"
# module fubar - function fAddBarBlue - function fAddPlot
fAddPlot(nParCollection=nCollection, # collection under analysis
         nParColor=fAddBarBlue(nParCollection=nCollection,nParIndex=-1)) # plot gray bar
# package matplotlib - module pyplot
xticks([])
savefig(fname=f"./rc/Unsorted/OuterNoneInnerNone.png")
close() # close figure window

# %%
# function call - fCountingSortPlot
fCountingSortPlot()

# %%
# define function - fCountingSort
def fCountingSort(nParCollection):
    nSetMaximumIndex=0 # set start index/position
    for nEachIndex in range(len(nParCollection)): # iterate collection indices
        if nParCollection[nEachIndex]>nSetMaximumIndex: # determine maximum element
            nSetMaximumIndex=nParCollection[nEachIndex] # maximum valued element 

    # each element zero
    nBuckets=[0]*(nSetMaximumIndex+1) # length maximum element+1
    
    for nEachElement in nParCollection: # iterate collection elements
        nBuckets[nEachElement]+=1 # populate discrete indices
    # bucket includes indices 
    
    nIndexReset=0 # set start index/position
    for nEachElement in range(nSetMaximumIndex+1): # iterate bucket length
        for nBucketElement in range(nBuckets[nEachElement]): # iterate bucket zeros
            nParCollection[nIndexReset]=nEachElement # populate count zeros 
            nIndexReset+=1 # move next index/position
            
    return nParCollection
# --- END ---

# %%
# function call - fCountingSort
fCountingSort(nParCollection=nCollection)
# module fubar - function fAddPlotTabs
fAddPlotTabs(nParAlgorithm=fCountingSort.__name__[1:]) # report plot tabs
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-cG4WmAUYConM7w2d7RupT8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-cG4WmAUYConM7w2d7RupT8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-cG4WmAUYConM7w2d7RupT8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-cG4WmAUYConM7w2d7RupT8:checked ~ #ipyplot-html-viewer-textarea-cG4WmAUYConM7w2d7RupT8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-cG4WmAUYConM7w2d7RupT8:checked + #ipyplot-html-viewer-label-cG4WmAUYConM7w2d7RupT8:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-cG4WmAUYConM7w2d7RupT8">
#         <label id="ipyplot-html-viewer-label-cG4WmAUYConM7w2d7RupT8" for="ipyplot-html-viewer-toggle-cG4WmAUYConM7w2d7RupT8">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-cG4WmAUYConM7w2d7RupT8" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4 {
#                 display: none;
#             }
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4 + label.ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4:checked + label.ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4 ~ .tab {
#                 display: none
#             }
#     #tabVwVpSsxzj6R45swr8RWsaF:checked ~ .tab.contentVwVpSsxzj6R45swr8RWsaF,#tabC3iRD46KK5pvubj7U6NPA5:checked ~ .tab.contentC3iRD46KK5pvubj7U6NPA5,#tabYsuFsDtXhmvVY2ZgSteCAk:checked ~ .tab.contentYsuFsDtXhmvVY2ZgSteCAk{ display: block; }</style><input class="ipyplot-tab-msHnK5VKdCYcqxnnouy9P4" type="radio" name="tabs-msHnK5VKdCYcqxnnouy9P4" id="tabVwVpSsxzj6R45swr8RWsaF" checked /><label class="ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4" for="tabVwVpSsxzj6R45swr8RWsaF">Collection</label><input class="ipyplot-tab-msHnK5VKdCYcqxnnouy9P4" type="radio" name="tabs-msHnK5VKdCYcqxnnouy9P4" id="tabC3iRD46KK5pvubj7U6NPA5"/><label class="ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4" for="tabC3iRD46KK5pvubj7U6NPA5">Histogram</label><input class="ipyplot-tab-msHnK5VKdCYcqxnnouy9P4" type="radio" name="tabs-msHnK5VKdCYcqxnnouy9P4" id="tabYsuFsDtXhmvVY2ZgSteCAk"/><label class="ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4" for="tabYsuFsDtXhmvVY2ZgSteCAk">Sorted</label><div class="tab contentVwVpSsxzj6R45swr8RWsaF">
#         <style>
#         #ipyplot-imgs-container-div-HNtcXCEzo2CumYQtC4qNr3 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HNtcXCEzo2CumYQtC4qNr3 {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-HNtcXCEzo2CumYQtC4qNr3">
#     <div class="ipyplot-placeholder-div-HNtcXCEzo2CumYQtC4qNr3">
#         <div id="ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3-k4aQ4udC4oe229zheQesuR" class="ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3-k4aQ4udC4oe229zheQesuR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentC3iRD46KK5pvubj7U6NPA5">
#         <style>
#         #ipyplot-imgs-container-div-YEbTSvBBzyP2gqeBjjnCEH {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-YEbTSvBBzyP2gqeBjjnCEH {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         di
# <div>
#         <style>
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4 {
#                 display: none;
#             }
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4 + label.ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4:checked + label.ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-msHnK5VKdCYcqxnnouy9P4 ~ .tab {
#                 display: none
#             }
#     #tabVwVpSsxzj6R45swr8RWsaF:checked ~ .tab.contentVwVpSsxzj6R45swr8RWsaF,#tabC3iRD46KK5pvubj7U6NPA5:checked ~ .tab.contentC3iRD46KK5pvubj7U6NPA5,#tabYsuFsDtXhmvVY2ZgSteCAk:checked ~ .tab.contentYsuFsDtXhmvVY2ZgSteCAk{ display: block; }</style><input class="ipyplot-tab-msHnK5VKdCYcqxnnouy9P4" type="radio" name="tabs-msHnK5VKdCYcqxnnouy9P4" id="tabVwVpSsxzj6R45swr8RWsaF" checked /><label class="ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4" for="tabVwVpSsxzj6R45swr8RWsaF">Collection</label><input class="ipyplot-tab-msHnK5VKdCYcqxnnouy9P4" type="radio" name="tabs-msHnK5VKdCYcqxnnouy9P4" id="tabC3iRD46KK5pvubj7U6NPA5"/><label class="ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4" for="tabC3iRD46KK5pvubj7U6NPA5">Histogram</label><input class="ipyplot-tab-msHnK5VKdCYcqxnnouy9P4" type="radio" name="tabs-msHnK5VKdCYcqxnnouy9P4" id="tabYsuFsDtXhmvVY2ZgSteCAk"/><label class="ipyplot-tab-label-msHnK5VKdCYcqxnnouy9P4" for="tabYsuFsDtXhmvVY2ZgSteCAk">Sorted</label><div class="tab contentVwVpSsxzj6R45swr8RWsaF">
#         <style>
#         #ipyplot-imgs-container-div-HNtcXCEzo2CumYQtC4qNr3 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HNtcXCEzo2CumYQtC4qNr3 {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-HNtcXCEzo2CumYQtC4qNr3">
#     <div class="ipyplot-placeholder-div-HNtcXCEzo2CumYQtC4qNr3">
#         <div id="ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3-k4aQ4udC4oe229zheQesuR" class="ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 1.</h4><img src="./rc/Unsorted/OuterNoneInnerNone.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HNtcXCEzo2CumYQtC4qNr3-k4aQ4udC4oe229zheQesuR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentC3iRD46KK5pvubj7U6NPA5">
#         <style>
#         #ipyplot-imgs-container-div-YEbTSvBBzyP2gqeBjjnCEH {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-YEbTSvBBzyP2gqeBjjnCEH {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH {
#             width: 325px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH img {
#             width: 325px;
#         }
#
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-YEbTSvBBzyP2gqeBjjnCEH">
#     <div class="ipyplot-placeholder-div-YEbTSvBBzyP2gqeBjjnCEH">
#         <div id="ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH-YSuzTNb39NcnhyGU9QM6kP" class="ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">Fig. 2.</h4><img src="./rc/Process/0.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YEbTSvBBzyP2gqeBjjnCEH-YSuzTNb39NcnhyGU9QM6kP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentYsuFsDtXhmvVY2ZgSteCAk">
#         <style>
#         #ipyplot-imgs-container-div-gtMBq65ej9KSypt9soYCpQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gtMBq65ej9KSypt9soYCpQ {
#             width: 325px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gtMBq65ej9KSypt9soYCpQ {
#             width:

# %% [markdown]
# &#x1F6A7; screenshot/save for reference

# %%
# %%script bash
# # copy local URLs / clean working URLs
# rm -rf ./rc/CountingSort/Unsorted; mv ./rc/Unsorted ./rc/CountingSort/; mkdir ./rc/Unsorted
# rm -rf ./rc/CountingSort/Process; mv ./rc/Process ./rc/CountingSort/; mkdir ./rc/Process
# rm -rf ./rc/CountingSort/Partition; mv ./rc/Partition ./rc/CountingSort/; mkdir ./rc/Partition
# rm -rf ./rc/CountingSort/Sorted; mv ./rc/Sorted ./rc/CountingSort/; mkdir ./rc/Sorted

# %% [markdown]
# ###### Re-Run
# ***
# < [Build Interactive Tabs](#buildPlotImageInteractiveTabs) >

# %%
exit()

# %% [markdown]
# # END JUPYTER NOTEBOOK
